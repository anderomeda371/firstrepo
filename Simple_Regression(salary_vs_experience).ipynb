# %% [markdown]
# <a href="https://colab.research.google.com/github/anderomeda371/firstrepo/blob/main/Simple_Regression(salary_vs_experience).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_csv("/content/Salary_Data.csv")

dataset[dataset.isnull().any(axis=1)]

X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=regressor.predict(X_test)
from sklearn.metrics import accuracy_score
# accuracy=accuracy_score(y_predict,y_test)
# accuracy

# %%
plt.scatter(X_train,y_train,c="red",label="train")
plt.scatter(X_test,y_test,c="green",label="test")
plt.plot(X_train,regressor.predict(X_train),label="Reggression Line")
plt.xlabel("YEAR of EXPERIeNCE")
plt.title("INCOME vs Experience Chart")
plt.ylabel("INCOME")
plt.legend()
